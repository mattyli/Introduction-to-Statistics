# %% [markdown]
# # Week 12 Quiz

# %%
data = read.csv("StressReliefD.csv", colClasses=c('factor', 'factor', 'numeric'))
boxplot(StressReduction~Treatment+Gender, data=data)
# Out:
# plot without title

# %%
interaction.plot(data$Treatment, data$Gender, data$StressReduction, type='b')
# Out:
# plot without title

# %%
model = lm(StressReduction~Gender * Treatment, data=data)
summary(model)
# Out:
# Call:
# lm(formula = StressReduction ~ Gender * Treatment, data = data)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -14.60  -5.65   1.00   6.60  13.10
#
# Coefficients:
#                           Estimate Std. Error t value Pr(>|t|)
# (Intercept)                 22.900      2.690   8.513 1.48e-11 ***
# GenderM                     -3.900      3.804  -1.025    0.310
# Treatmentmental              1.600      3.804   0.421    0.676
# Treatmentphysical            2.500      3.804   0.657    0.514
# GenderM:Treatmentmental      1.000      5.380   0.186    0.853
# GenderM:Treatmentphysical    2.400      5.380   0.446    0.657
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 8.506 on 54 degrees of freedom
# Multiple R-squared:  0.06398,	Adjusted R-squared:  -0.02268
# F-statistic: 0.7383 on 5 and 54 DF,  p-value: 0.5981

# %%
summary(aov(model))
# Out:
#                  Df Sum Sq Mean Sq F value Pr(>F)
# Gender            1    115  114.82   1.587  0.213
# Treatment         2    138   68.87   0.952  0.392
# Gender:Treatment  2     15    7.27   0.100  0.905
# Residuals        54   3907   72.35
