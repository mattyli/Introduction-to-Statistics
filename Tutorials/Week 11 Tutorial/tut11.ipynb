# %% [markdown]
# # Week 11 Tutorial - Linear Regression and Correlation

# %%
data = read.csv("mediasexism.csv", colClasses=c('factor', 'factor','numeric','numeric', 'numeric'))
plot(data$Expert, data$Seats, xlab="number of articles depicting candidates as 'experts'", ylab="number of seats held", main="number of seats held vs number of stories depicting candidates as experts")
# Out:
# Plot with title "number of seats held vs number of stories depicting candidates as experts"

# %% [markdown]
# 1) there is no apparent relationship between the number of articles and the number of seats held.
#
# 2) H0 : There is not a linear relationship between the number of articles and the number of seats held.
#    HA : There is a linear relationship.

# %%
seats = data$Seats # Y or the response
articles = data$Expert # X or the predictor

model = lm(seats~articles)
model
# Out:
# Call:
# lm(formula = seats ~ articles)
#
# Coefficients:
# (Intercept)     articles
#     17.6702       0.1631

# %%
plot(data$Expert, data$Seats, xlab="number of articles depicting candidates as 'experts'", ylab="number of seats held", main="number of seats held vs number of stories depicting candidates as experts")
abline(model, col="red", lwd=3)
# Out:
# Plot with title "number of seats held vs number of stories depicting candidates as experts"

# %%
summary(model)
# Out:
# Call:
# lm(formula = seats ~ articles)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -19.217  -9.806  -2.252   9.400  23.416
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  17.6702     3.3277   5.310 2.03e-06 ***
# articles      0.1631     0.1364   1.196    0.237
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 11.35 on 55 degrees of freedom
# Multiple R-squared:  0.02535,	Adjusted R-squared:  0.007627
# F-statistic:  1.43 on 1 and 55 DF,  p-value: 0.2368

# %%
# Residual plot
plot(model, 1)
# Out:
# Plot with title ""

# %%
hist(residuals(model),main="",xlab="Residuals",freq=FALSE)
res=residuals(model)
curve(dnorm(x,0,sd(res)), add=TRUE,col="blue")
# Out:
# Plot with title ""

# %%
shapiro.test(residuals(model))
# Out:
# 	Shapiro-Wilk normality test
#
# data:  residuals(model)
# W = 0.93833, p-value = 0.006009
